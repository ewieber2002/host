# %% [markdown]
# <h1>HW 3</H1>
#
# **EE/PHY 448/548**
#
# **Scott Prahl**
#
# **17 Apr 2019, Version 1**

# %% [markdown]
# # Reading for next week
#
# * Young, &ldquo;Experiments and Calculations Related to Physical Optics,&rdquo; (BlackBoard)
# * *and reread* Fowles, *Introduction to Modern Optics*, Section 3.2
# * *and* Peatross, *Physics of Light and Optics*, Section 8.5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problems
#
# ## Problem 1 (10 points)
# Two waves traveling together along the same line are given by $y_1 = 5 \sin(\omega t + \pi/2)$ and $y_2 = 7 \sin (\omega t + \pi/3)$. Use the trigonometry to find the equation for the sum.

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %%
# validate solution
t = np.linspace(0,3,30)
plt.plot(t,5*np.sin(3*t+np.pi/2)+7*np.sin(3*t+np.pi/3),'x')
plt.plot(t, 11.6*np.sin(3*t + 1.264))
plt.show()

# %% [markdown]
# ## Problem 2 (10 points)
# Six waves of equal amplitude and period but differing from the previous by 16$^\circ$ are added together.  If the amplitude is 5, then what amplitude and phase of the sum of all six?

# %%
# YOUR CODE HERE
raise NotImplementedError()
# Out:
# phase     = 40.00°
# amplitude = 26.70

# %% [markdown]
# ## Problem 3
#
# Standing waves are produced by the superposition of two waves,
# $$
# y_1= 7\sin 2\pi\left({t\over T}-{2x\over\pi}\right)
# \qquad\mbox{and}\qquad
# y_2= 7\sin 2\pi\left({t\over T}+{2x\over\pi}\right)
# $$

# %% [markdown]
# ### Problem 3a (5 points)
# Plot the standing wave $y_1+y_2$ for $0\le x\le 4$.  Make sure you show the entire range of amplitudes (over time) at each position.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Problem 3b (5 points)
# Use trig to simplify the equation for the standing wave.  Use the simpler equation to find its amplitude, wavelength, period, and velocity.

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 4 (5 points)
# Recall that the irradiance $I$ is the time average of the Poynting vector $\bf S$
# $$
# I = \langle \mathbf{S} \rangle = \frac{1}{2} \mathbf{E} \times \mathbf{H} = \frac{n}{2 Z_0} E\cdot E^*
# $$
# related to the electric field $E$
# $$
# I = \frac{1}{Z_0} E\cdot E^*
# $$
# where $Z_0$ is the [impedance of free space](https://en.wikipedia.org/wiki/Impedance_of_free_space)
#
# What are the units for $I$, $Z_0$, and $E$?  Show that they are consistent using Ohm's law.  (Note that this commonly used term intensity should actually be called the irradiance.)

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 5 (10 points)
#
# Two waves have plane waves travelling in medium with index $n$ have fields given by $E_1\exp(i\omega t+i\alpha_1)$ and $E_2\exp(i\omega t + i\alpha_2)$.  When these fields interfere
#
# * What is the total field?
#
# * What is the complex conjugate of the total field?
#
# * What is the intensity?
#
# * What is the maximum and minimum intensity?

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 6
# For the following, assume that the wavelength of light in a vacuum is $\lambda_0=500$nm
#
# ### Problem 6a (5 points)
# How many waves span a 100mm gap in a vacuum?

# %%
d_vacuum=100e-3
lambda0=500e-9
# YOUR CODE HERE
raise NotImplementedError()
print("Exactly %d wavelengths will span the gap" %N)
# Out:
# Exactly 200000 wavelengths will span the gap

# %% [markdown]
# ### Problem 6b (5 points)
# How many waves are needed when a glass plate 5mm thick ($n = 1.5$) is inserted in the path?

# %%
n=1.5
d_glass=5e-3
d_total=100e-3
lambda0=500e-9
# YOUR CODE HERE
raise NotImplementedError()
print("Exactly %d wavelengths are now needed" %N)
# Out:
# Exactly 205000 wavelengths are now needed

# %% [markdown]
# ### Problem 6c (5 points)
# Determine the optical path difference between the two situations.

# %%
n=1.5
d_glass=5e-3
d_total=100e-3
lambda0=500e-9

# YOUR CODE HERE
raise NotImplementedError()

print("The optical path difference is %.2f mm" % (1000*optical_path_difference))
# Out:
# The optical path difference is 2.50 mm

# %% [markdown]
# ## Problem 7 (5 points)
# If you strike two tuning forks, one with a frequency of 392Hz (G above middle C) and the other at 440Hz (A above middle C). What will you hear?  Be specific.

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 8 (10 points) (550 Students)
# The waveform $E_0(1 + a \cos \omega_m t) \cos \omega_c t$ has a carrier frequency $\omega_c$ modulated at $\omega_m$
#
# <img src="https://omlc.org/~prahl/host/450/week3/beat.pdf" width="50%">
#
# Show that this wave is the sum of three cosine waves with different frequencies: the carrier frequency $\omega_c$, an upper sideband frequency $\omega_c+\omega_m$, and a lower sideband frequency of $\omega_c-\omega_m$.

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 9 (5 points)
# Given the dispersion relation to $\omega = a k^2$, compute both the phase and group velocities.

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 10 (550 students)
#
# The `rect()` function and its Fourier transform is
# $$
# \mathrm{rect}(t/\tau) = \cases{ 1 & $|t|<\tau/2$; \cr
#                   0 & otherwise}
#                   \qquad\mbox{and}\qquad
#                   \mathcal{F}[\mathrm{rect}(t/\tau)] = |\tau| \mathrm{sinc}(\omega \tau/2)
# $$

# %% [markdown]
# ### Problem 10a (5 points)
# Define a python function `rect()` and **plot** $\mathrm{rect}(t/\tau)$ for $\tau=0.1$ and 1

# %%
t=np.linspace(-1.5,1.5,200)

# YOUR CODE HERE
raise NotImplementedError()

for tau in [0.1, 1]:
    plt.plot(t,rect(t/tau),label=r"$\tau$=%.1f"% tau)
plt.xlabel('t')
plt.ylabel(r'rect(t/$\tau$)')
plt.legend()
plt.show()

# %% [markdown]
# ### Problem 10b (5 points)
# Define a python function `sinc()` and **plot** $\tau \mathrm{sinc}(\tau \omega /2)$  for $\tau=0.1$ and 1. (note that `numpy.sinc()` differs from that used in the optics world where $\mathrm{sinc}(x)\equiv (\sin x)/x$

# %%
omega =np.linspace(-100,100,1000)

# YOUR CODE HERE
raise NotImplementedError()

for tau in [0.1, 1]:
    plt.plot(omega,tau*sinc(tau*omega/2),label=r"$\tau$=%.1f"% tau)
plt.axhline(0,color='black',linestyle=':')
plt.xlabel(r'$\omega$')
plt.ylabel(r'$\tau\cdot$sinc($\omega\tau$/2)')
plt.legend()
plt.show()

# %% [markdown]
# ### Problem 10c (10 points)
# How would you define the bandwidth of the pulse based on its Fourier Transform?

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ## Problem 11
#
# Young's experiment is one of the most elegant experiments in physics.  Read the following and answer the subsequent questions.
#
# EXPERIMENTS AND CALCULATIONS RELATIVE TO PHYSICAL OPTICS, Thomas Young, 1803
#
# >IN making some experiments on the fringes of colors accompanying shadows, I have found so simple and so demonstrative a proof of the general law of the interference of two portions of light, which I have already endeavored to establish, that I think it right to lay before the Royal Society a short statement of the facts which appear to me so decisive. The proposition on which I mean to insist at present is simply this — that fringes of colors are produced by the interference of two portions of light; and I think it will not be denied by the most prejudiced that the assertion is proved by the experiments I am about to relate, which may be repeated with great ease whenever the sun shines, and without any other apparatus than is at hand to everyone.
#
# >*Experiment 1.* I made a small hole in a window-shutter, and covered it with a piece of thick paper, which I perforated with a fine needle. For greater convenience of observation I placed a small looking-glass without the window-shutter, in such a position as to reflect the sun's light in a direction nearly horizontal upon the opposite wall, and to cause the cone of diverging light to pass over a table on which were several little screens of card-paper. I brought into the sunbeam a slip of card about one-thirtieth of an inch in breadth, and observed its shadow, either on the wall or on other cards held at different distances. Besides the fringes of color on each side of the shadow, the shadow itself was divided by similar parallel fringes of smaller dimensions, differing in number according to the distance at which the shadow was observed, but leaving the middle of the shadow always white. Now these fringes were the joint effects of the portions of light passing on each side of the slip of card, and inflected, or rather diffracted, into the shadow; for a little screen being placed a few inches from the card so as to receive either edge of the shadow on its margin, all the fringes which had before been observed in the shadow on the wall immediately disappeared, although the light inflected on the other side was allowed to retain its course, and although this light must have undergone any modification that the proximity of the other edge of the slip of card might have been capable of occasioning. When the interposed screen was more remote from the narrow card, it was necessary to plunge it more deeply into the shadow, in order to extinguish the parallel lines; for here the light diffracted from the edge of the object had entered farther into the shadow in its way towards the fringes. Nor was it for want of a sufficient intensity of light that one of the two portions was incapable of producing the fringes alone; for when they were both uninterrupted, the lines appeared, even if the intensity was reduced to one-tenth or one-twentieth.

# %% [markdown]
# ### Problem 11a  (5 points)
# Explain what is going on with the shutter and thick paper

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ### Problem 11b   (5 points)
#
# Explain what a "looking glass" is and why it is convenient

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ### Problem 11c  (10 points)
#
# The sunbeam diverges.
#
# * Estimate the sunbeam size after the thick paper on the window.
#
# * What is the thickness of the "slip of card"?
#
# * How much does the sunbeam diverge?
#
# * At what distance from the window should the "slip of card" be placed?

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %% [markdown]
# ### Problem 11d (30 points) (550 Students)
#
# Design the screen location so that you might conveniently observe the diffraction pattern.

# %%
lambda0 = 550e-9

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### Problem 11e (10 points)
#
# Young's article has no pictures, so to prove you understand, you must sketch the first experiment.
#
# * Show the dimensions between every optical element.
# * Label and explain the sizes and spacing of **slits** as well as **pinhole** sizes
#
# **If a dimension is unknown, make an educated guess.**

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ### (Extra Credit) (50 points)
#
# Replicate Young's experiment

# %% [markdown]
# ---
# ## <span style="color:red">Student Answer</span>
#
# *Double-click and add your answer between the lines*
#
# ---

# %%
#HIDDEN
print("total points 450 = %d" % total_points_450)
print("total points 550 = %d" % total_points_550)
# Out:
# total points 450 = 100
# total points 550 = 70
